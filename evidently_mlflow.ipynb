# %% [markdown]
# Complete Guide to Effortless ML Monitoring with Evidently.ai

# %% [markdown]
# # Integrate Evidently with MLflow

# %%
# Step1: Install All the Necessary Packages

# %%
pip install mlflow requests pyarrow psycopg psycopg_binary
# Out:
# Collecting mlflowNote: you may need to restart the kernel to use updated packages.
#
#   Downloading mlflow-2.11.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in c:\users\sudwa\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: pyarrow in c:\users\sudwa\anaconda3\lib\site-packages (11.0.0)
# Collecting psycopg
#   Downloading psycopg-3.1.18-py3-none-any.whl.metadata (4.2 kB)
# Collecting psycopg_binary
#   Downloading psycopg_binary-3.1.18-cp311-cp311-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: entrypoints<1 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\sudwa\appdata\roaming\python\python311\site-packages (from mlflow) (3.1.32)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\sudwa\appdata\roaming\python\python311\site-packages (from mlflow) (4.23.4)
# Requirement already satisfied: pytz<2025 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: packaging<24 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (23.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (6.0.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow)
#   Using cached sqlparse-0.4.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: Flask<4 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: numpy<2 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (1.24.3)
# Requirement already satisfied: scipy<2 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (1.11.1)
# Requirement already satisfied: pandas<3 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (2.0.3)
# Collecting querystring-parser<2 (from mlflow)
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: scikit-learn<2 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (3.7.2)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting waitress<4 (from mlflow)
#   Using cached waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\sudwa\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sudwa\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sudwa\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sudwa\anaconda3\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sudwa\anaconda3\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.1 in c:\users\sudwa\anaconda3\lib\site-packages (from psycopg) (4.7.1)
# Requirement already satisfied: tzdata in c:\users\sudwa\appdata\roaming\python\python311\site-packages (from psycopg) (2023.3)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached Mako-1.3.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\sudwa\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: pywin32>=304 in c:\users\sudwa\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\sudwa\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\sudwa\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sudwa\appdata\roaming\python\python311\site-packages (from gitpython<4,>=3.1.9->mlflow) (4.0.10)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting aniso8601<10,>=8 (from graphene<4->mlflow)
#   Using cached aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\sudwa\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sudwa\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sudwa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: six in c:\users\sudwa\anaconda3\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sudwa\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sudwa\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sudwa\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sudwa\appdata\roaming\python\python311\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (5.0.0)
# Downloading mlflow-2.11.3-py3-none-any.whl (19.7 MB)
#    ---------------------------------------- 0.0/19.7 MB ? eta -:--:--
#    ---------------------------------------- 0.2/19.7 MB 3.6 MB/s eta 0:00:06
#    ---------------------------------------- 0.2/19.7 MB 4.2 MB/s eta 0:00:05
#     --------------------------------------- 0.4/19.7 MB 3.0 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/19.7 MB 3.0 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/19.7 MB 2.7 MB/s eta 0:00:08
#    - -------------------------------------- 0.7/19.7 MB 2.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/19.7 MB 2.6 MB/s eta 0:00:08
#    - -------------------------------------- 1.0/19.7 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.0/19.7 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.1/19.7 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.2/19.7 MB 2.3 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/19.7 MB 2.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/19.7 MB 2.1 MB/s eta 0:00:09
#    -- ------------------------------------- 1.4/19.7 MB 2.0 MB/s eta 0:00:10
#    --- ------------------------------------ 1.5/19.7 MB 2.0 MB/s eta 0:00:10
#    --- ------------------------------------ 1.6/19.7 MB 2.0 MB/s eta 0:00:10
#    --- ------------------------------------ 1.7/19.7 MB 1.9 MB/s eta 0:00:10
#    --- ------------------------------------ 1.8/19.7 MB 1.9 MB/s eta 0:00:10
#    --- ------------------------------------ 1.9/19.7 MB 1.9 MB/s eta 0:00:10
#    --- ------------------------------------ 1.9/19.7 MB 1.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 2
using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Using cached sqlparse-0.4.4-py3-none-any.whl (41 kB)
# Using cached waitress-3.0.0-py3-none-any.whl (56 kB)
# Using cached aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Using cached graphql_core-3.2.3-py3-none-any.whl (202 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached Mako-1.3.2-py3-none-any.whl (78 kB)
# Installing collected packages: aniso8601, waitress, sqlparse, querystring-parser, psycopg_binary, psycopg, Mako, graphql-core, graphql-relay, docker, alembic, graphene, mlflow
# Successfully installed Mako-1.3.2 alembic-1.13.1 aniso8601-9.0.1 docker-7.0.0 graphene-3.3 graphql-core-3.2.3 graphql-relay-3.2.0 mlflow-2.11.3 psycopg-3.1.18 psycopg_binary-3.1.18 querystring-parser-1.2.4 sqlparse-0.4.4 waitress-3.0.0

# %%
mlflow ui --backend-store-uri sqlite:///mlflow.db
# Out:
#   Cell In[3], line 1
#     mlflow ui --backend-store-uri sqlite:///mlflow.db
#            ^
# SyntaxError: invalid syntax

# %%
import mlflow
import pandas as pd
from datetime import datetime, timedelta
from sklearn import datasets
from scipy import stats
import numpy as np
from evidently.test_suite import TestSuite
from evidently.test_preset import DataDriftTestPreset, DataQualityTestPreset, DataStabilityTestPreset

# %%
# Step 2: Define a Task to Load the Data From a CSV File

# %%
# Step 2: Define a task to perform data quality tests and generate a report
def data_processing(df):
    numerical_columns = [
        'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime','CRSArrTime',
        'FlightNum', 'CRSElapsedTime', 'AirTime', 'DepDelay',
        'Distance', 'TaxiIn', 'TaxiOut', 'CarrierDelay', 'WeatherDelay', 'NASDelay',
        'SecurityDelay', 'LateAircraftDelay']
    df=df.drop(['Unnamed: 0','Year','CancellationCode','TailNum','Diverted','Cancelled','ArrTime','ActualElapsedTime'],axis=1)
    delay_colns=['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']

    # Impute missing values with the 0 for these columns
    df[delay_colns]=df[delay_colns].fillna(0)

    # Impute missing values with the median for these columns
    columns_to_impute = ['AirTime', 'ArrDelay', 'TaxiIn','CRSElapsedTime']
    df[columns_to_impute]=df[columns_to_impute].fillna(df[columns_to_impute].median())


    df=pd.get_dummies(df,columns=['UniqueCarrier', 'Origin'], drop_first=True)
    z_threshold=3
    z_scores=np.abs(stats.zscore(df[numerical_columns]))
    outliers=np.where(z_scores>z_threshold)
    df_no_outliers=df[(z_scores<=z_threshold).all(axis=1)]
    return df_no_outliers

# %%
# Step 3: Set MLflow Tracking URI and Experiment

# %%
# Set MLflow tracking URI and experiment
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("Drift Test Suite")

# %%
# Step 4: Define Batch Size for Data Processing

# %%
batch_size=200000

# %%
# Step 5: Iterate through batches

# %%
for batch_id in range(3):
    with mlflow.start_run() as run:
        df, ref_data, curr_data =load_data()
        processed_df=data_processing(df)
        data_drift_suite = TestSuite(tests=[DataDriftTestPreset()])
        reference=df[1:500000]
        current=df[500000:]
        data_drift_suite.run(reference_data=reference, current_data=current[(batch_id*batch_size):(batch_id+1)*batch_size])
        if not data_drift_suite.as_dict()['summary']['all_passed']:
            data_drift_suite.save_html("Reports/data_drift_suite.html")

        mlflow.log_param("Sucessful tests", data_drift_suite.as_dict()['summary']['success_tests'])
        mlflow.log_param("Failure tests", data_drift_suite.as_dict()['summary']['failed_tests'])

        mlflow.log_artifact("Reports/data_drift_suite.html")
        print(run.info)
